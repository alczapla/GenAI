# %% [markdown]
# <a href="https://colab.research.google.com/github/alczapla/GenAI/blob/main/Assignment_1_The_GPT_2_Stress_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Model: GPT-2
# Results
#
# ![Model 1.png](data:image/png;base64,...)
#
#
# During the process of changing the temperature and reading the model prompts, it seemed to repeat some words or phrases. Since trial A showed many repeated words of the following world, place, and great, while Trial C only repeated “appeared” within its prompt. The model had no issues prompting real words nor random characters as the probability distribution was capable of properly determining what percentage within vocabulary will be the next correct word depending what temperature it is set on. Therefore if an organization wishes to use medical AI they should use the temperature closest to 0 to be most deterministic or conservative of the most likely next chosen word when it comes to correctly prescribing prescriptions or advice. As those who wish for surrealist dream-journal prompts, they can set the temperature from 0.8 - 2 depending on how the user wishes the prompts to generate general, creative or chaotic sentences.
#
#
# Model: DistilGPT-2
# Results
#
# ![Model 2.png](data:image/png;base64,...)
#
#
#
# Between the two models of GPT-2 and DistilGPT-2, I see they have fair similarities in coherence within Trials A and B when it comes to temperature. But in distilgpt-2 Trial C setting the temperature value to 2, shows the sentence to be fully gibberish along how it attempted to prompt “universe′st”. As well I noticed between the models seem to have different word filters that I believe are implemented as the models advance, for example many of distilgpt-2 prompts I ran provided more political parties such as mentioning the United States about war during conservative trials. Many tests with the model GPT-2 never attempted to add political parties when given the prompt “War between” when the temperature was set to 0.1 never specified who were the political parties other than countries.
